# %%
import torch

# Check if CUDA is available
if torch.cuda.is_available():
    print("CUDA is available.")
    print(f"Number of CUDA devices: {torch.cuda.device_count()}")
    print(f"Current CUDA device: {torch.cuda.current_device()}")
    print(f"Device name: {torch.cuda.get_device_name(torch.cuda.current_device())}")
else:
    print("CUDA is not available.")
# Out:
# CUDA is available.
# Number of CUDA devices: 1
# Current CUDA device: 0
# Device name: NVIDIA GeForce RTX 5060
# c:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\cuda\__init__.py:235: UserWarning:
# NVIDIA GeForce RTX 5060 with CUDA capability sm_120 is not compatible with the current PyTorch installation.
# The current PyTorch install supports CUDA capabilities sm_50 sm_60 sm_61 sm_70 sm_75 sm_80 sm_86 sm_90.
# If you want to use the NVIDIA GeForce RTX 5060 GPU with PyTorch, please check the instructions at https://pytorch.org/get-started/locally/
#
#   warnings.warn(

# %%
print(torch.version.cuda)
x = torch.randn(1000, 1000).cuda()
y = torch.matmul(x, x)
print(y.device)
# Out:
# 12.1
# cuda:0

# %%
# !nvidia-smi
# Out:
# Sat Feb  7 14:38:18 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 591.59                 Driver Version: 591.59         CUDA Version: 13.1     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 5060      WDDM  |   00000000:01:00.0  On |                  N/A |
# |  0%   42C    P8              9W /  145W |    1414MiB /   8151MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            2472    C+G   ...0.3719.115\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A            8388    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A            8428    C+G   ...indows\System32\ShellHost.exe      N/A      |
# |    0   N/A  N/A            8520    C+G   ...0.3719.115\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A            8728    C+G   ...yb3d8bbwe\Notepad\Notepad.exe      N/A      |
# |    0   N/A  N/A            8836    C+G   ...2txyewy\CrossDeviceResume.exe      N/A      |
# |    0   N/A  N/A            9380    C+G   ...s\Antigravity\Antigravity.exe      N/A      |
# |    0   N/A  N/A            9732    C+G   ...y\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A           10340    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           11032    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           11568    C+G   ...r\frontend\Docker Desktop.exe      N/A      |
# |    0   N/A  N/A           11868    C+G   ...IA App\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A           12092    C+G   ...5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A           12400    C+G   ...IA App\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A           13044    C+G   ...ntrolPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A           14464    C+G   ...em32\ApplicationFrameHost.exe      N/A      |
# |    0   N/A  N/A           14960    C+G   ..._cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A           16128    C+G   ...s\Antigravity\Antigravity.exe      N/A      |
# |    0   N/A  N/A           17180      C   ...s\Python\Python310\python.exe      N/A      |
# |    0   N/A  N/A           17940    C+G   ...xyewy\ShellExperienceHost.exe      N/A      |
# +-----------------------------------------------------------------------------------------+
